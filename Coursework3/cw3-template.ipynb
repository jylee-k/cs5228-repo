# %% [markdown]
# ## Coursework 3 Template
# ### CS5228- 2025/26-2

# %%
# Graph Mining Homework: Facebook Social Network

import networkx as nx
import matplotlib.pyplot as plt
import random

# 1. Load the dataset

# 2. Basic Graph Properties

# 3. Node-Level Analysis
# Degree centrality

# Betweenness centrality


# 4. Community Detection (Girvan-Newman)


# 5. Shortest Paths
# Pick two nodes from the largest component

# 6. Visualization

# 7. Extra

# %%
# import any other library that you like
# add any part and markup cells that you need
